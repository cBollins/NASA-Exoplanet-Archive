# %% [markdown]
# # Plot 4: Planet density vs planet radius

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Define some global constants
plt.rcParams["figure.figsize"] = (12.8, 7.2)
plt.rcParams["axes.labelsize"] = 14
plt.rcParams["axes.titlesize"] = 16 
plt.rcParams["legend.fontsize"] = 12 
plt.rcParams["legend.title_fontsize"] = 14
plt.rcParams["xtick.labelsize"] = 12
plt.rcParams["ytick.labelsize"] = 12
plt.rcParams["lines.markersize"] = 6
plt.rcParams["lines.linewidth"] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams["grid.alpha"] = 0.3

df = pd.read_csv("plots_data.csv")

# what do we care about?
# density, radius and method
df = df[["pl_dens", "pl_rade", "discoverymethod"]]
df.dropna(inplace=True)
df.head()
# Out:
#      pl_dens    pl_rade discoverymethod
# 1      0.400  14.616536         Transit
# 5      0.490  13.103321         Transit
# 6      0.352  14.830000         Transit
# 16     0.492  13.103321         Transit
# 113    1.910   2.340000         Transit

# %%
# how many planets are there where we know both the radius and the density?
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2309 entries, 1 to 38504
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pl_dens          2309 non-null   float64
#  1   pl_rade          2309 non-null   float64
#  2   discoverymethod  2309 non-null   object
# dtypes: float64(2), object(1)
# memory usage: 72.2+ KB

# %%
# This code is directly copied and adapted from "Plot_1.ipynb"

methods = df["discoverymethod"].unique()
print(methods)

# create a colourmap based on the methods
import seaborn as sns

fig, ax = plt.subplots()
sns.scatterplot(
    data=df, 
    x="pl_dens", 
    y="pl_rade", 
    hue="discoverymethod", 
    style="discoverymethod",
    palette=sns.hls_palette(len(methods)), 
    ax=ax,
    s=40
)

# want a log-log
ax.set_xscale("log")
ax.set_yscale("log")

ax.legend(title="Discovery Method")
plt.title("Log-Log plot of Exoplanet Mass vs. Orbital Period")
ax.set_xlabel(r"Exoplanet Density [$\rho_\text{E}$]")
ax.set_ylabel(r"Exoplanet Radius [$\text{R}_\text{e}$]")

plt.tight_layout()
plt.show()
# Out:
# ['Transit' 'Radial Velocity' 'Orbital Brightness Modulation'
#  'Transit Timing Variations']

# %% [markdown]
# # Discussion
#
# ...
